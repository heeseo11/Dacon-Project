# %% [markdown]
# # **1. 데이터 및 라이브러리 불러오기**

# %%
! pip install konlpy
# !pip install transformers==3.3.0
! pip install sentencepiece
# Out:
# Requirement already satisfied: konlpy in /usr/local/lib/python3.7/dist-packages (0.5.2)
# Requirement already satisfied: JPype1>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from konlpy) (1.3.0)
# Requirement already satisfied: beautifulsoup4==4.6.0 in /usr/local/lib/python3.7/dist-packages (from konlpy) (4.6.0)
# Requirement already satisfied: tweepy>=3.7.0 in /usr/local/lib/python3.7/dist-packages (from konlpy) (3.10.0)
# Requirement already satisfied: lxml>=4.1.0 in /usr/local/lib/python3.7/dist-packages (from konlpy) (4.2.6)
# Requirement already satisfied: colorama in /usr/local/lib/python3.7/dist-packages (from konlpy) (0.4.4)
# Requirement already satisfied: numpy>=1.6 in /usr/local/lib/python3.7/dist-packages (from konlpy) (1.19.5)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from JPype1>=0.7.0->konlpy) (3.7.4.3)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from tweepy>=3.7.0->konlpy) (1.3.0)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.7/dist-packages (from tweepy>=3.7.0->konlpy) (1.15.0)
# Requirement already satisfied: requests[socks]>=2.11.1 in /usr/local/lib/python3.7/dist-packages (from tweepy>=3.7.0->konlpy) (2.23.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->tweepy>=3.7.0->konlpy) (3.1.1)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests[socks]>=2.11.1->tweepy>=3.7.0->konlpy) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests[socks]>=2.11.1->tweepy>=3.7.0->konlpy) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests[socks]>=2.11.1->tweepy>=3.7.0->konlpy) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests[socks]>=2.11.1->tweepy>=3.7.0->konlpy) (2021.5.30)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.7/dist-packages (from requests[socks]>=2.11.1->tweepy>=3.7.0->konlpy) (1.7.1)
# Requirement already satisfied: transformers==3.3.0 in /usr/local/lib/python3.7/dist-packages (3.3.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from transformers==3.3.0) (2.23.0)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.7/dist-packages (from transformers==3.3.0) (4.41.1)
# Requirement already satisfied: sacremoses in /usr/local/lib/python3.7/dist-packages (from transformers==3.3.0) (0.0.45)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers==3.3.0) (2019.12.20)
# Requirement already satisfied: tokenizers==0.8.1.rc2 in /usr/local/lib/python3.7/dist-packages (from transformers==3.3.0) (0.8.1rc2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from transformers==3.3.0) (1.19.5)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from transformers==3.3.0) (21.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers==3.3.0) (3.0.12)
# Requirement already satisfied: sentencepiece!=0.1.92 in /usr/local/lib/python3.7/dist-packages (from transformers==3.3.0) (0.1.96)
# Requirement already satisfied: pyparsing>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->transformers==3.3.0) (2.4.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->transformers==3.3.0) (2021.5.30)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->transformers==3.3.0) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->transformers==3.3.0) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->transformers==3.3.0) (2.10)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers==3.3.0) (1.0.1)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers==3.3.0) (7.1.2)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers==3.3.0) (1.15.0)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.7/dist-packages (0.1.96)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import re
import json
import os
import tqdm

from konlpy.tag import Okt

import sklearn
from sklearn.preprocessing import LabelEncoder

from sklearn.metrics import log_loss, accuracy_score,f1_score
import tensorflow as tf
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from transformers import *

# %%
from google.colab import drive
drive.mount('/content/gdrive/')
# Out:
# Drive already mounted at /content/gdrive/; to attempt to forcibly remount, call drive.mount("/content/gdrive/", force_remount=True).

# %%
train = pd.read_csv('/content/gdrive/MyDrive/dacon 자연어 기반 기후 기술 분류/dacon_자연어기반 기후기술분류/open/train.csv')
test = pd.read_csv('/content/gdrive/MyDrive/dacon 자연어 기반 기후 기술 분류/dacon_자연어기반 기후기술분류/open/test.csv')
sample_submission = pd.read_csv('/content/gdrive/MyDrive/dacon 자연어 기반 기후 기술 분류/dacon_자연어기반 기후기술분류/open/sample_submission.csv')

# %% [markdown]
# # **2. 데이터 EDA**

# %%
train.head(2)
# Out:
#    index  제출년도  ...                                          요약문_영문키워드 label
# 0      0  2016  ...  nucleotide sequence, molecular marker, species...    24
# 1      1  2019  ...  TRAIL,Colorectal cancer,TRAIL resistance,Apopt...     0
#
# [2 rows x 13 columns]

# %%
test.head(2)
# Out:
#     index  ...                                          요약문_영문키워드
# 0  174304  ...  Friction Stir Spot Welding, Non-destructive ev...
# 1  174305  ...  many particle system,stability of dynamics,qua...
#
# [2 rows x 12 columns]

# %%
sample_submission.head(6)
# Out:
#     index  label
# 0  174304      0
# 1  174305      0
# 2  174306      0
# 3  174307      0
# 4  174308      0
# 5  174309      0

# %%
train.columns
# Out:
# Index(['index', '제출년도', '사업명', '사업_부처명', '계속과제여부', '내역사업명', '과제명', '요약문_연구목표',
#        '요약문_연구내용', '요약문_기대효과', '요약문_한글키워드', '요약문_영문키워드', 'label'],
#       dtype='object')

# %%
test.columns
# Out:
# Index(['index', '제출년도', '사업명', '사업_부처명', '계속과제여부', '내역사업명', '과제명', '요약문_연구목표',
#        '요약문_연구내용', '요약문_기대효과', '요약문_한글키워드', '요약문_영문키워드'],
#       dtype='object')

# %%
#데이터 구조 파악
print(train.shape)
print(test.shape)
print(sample_submission.shape)
# Out:
# (174304, 13)
# (43576, 12)
# (43576, 2)

# %%
#심각한 불균형 데이터임을 알 수 있습니다.
train.label.value_counts(sort=False)/len(train)
# Out:
# 0     0.817945
# 1     0.007234
# 2     0.001578
# 3     0.000820
# 4     0.000327
# 5     0.009742
# 6     0.000447
# 7     0.000648
# 8     0.001945
# 9     0.000608
# 10    0.003775
# 11    0.001147
# 12    0.001538
# 13    0.003299
# 14    0.009592
# 15    0.000947
# 16    0.002903
# 17    0.000884
# 18    0.008893
# 19    0.028330
# 20    0.006076
# 21    0.002846
# 22    0.000849
# 23    0.010556
# 24    0.020195
# 25    0.004647
# 26    0.001813
# 27    0.003557
# 28    0.002576
# 29    0.005898
# 30    0.001342
# 31    0.005290
# 32    0.001492
# 33    0.003058
# 34    0.003001
# 35    0.001669
# 36    0.006081
# 37    0.001526
# 38    0.001503
# 39    0.001159
# 40    0.002530
# 41    0.000384
# 42    0.000293
# 43    0.002014
# 44    0.000522
# 45    0.006523
# Name: label, dtype: float64

# %%
length=train['과제명'].astype(str).apply(len)
plt.hist(length, bins=50, alpha=0.5, color='r', label='word')
plt.title('histogram of length of task_name')
plt.figure(figsize=(12, 5))
plt.boxplot(length, labels=['counts'], showmeans=True)
print('과제명 길이 최댓값: {}'.format(np.max(length)))
print('과제명 길이 최솟값: {}'.format(np.min(length)))
print('과제명 길이 평균값: {}'.format(np.mean(length)))
print('과제명 길이 중간값: {}'.format(np.median(length)))
# Out:
# 과제명 길이 최댓값: 229
# 과제명 길이 최솟값: 2
# 과제명 길이 평균값: 35.84252225995961
# 과제명 길이 중간값: 34.0

# %%
length=train['요약문_연구목표'].astype(str).apply(len)
plt.hist(length, bins=50, alpha=0.5, color='r', label='word')
plt.title('histogram of length of summary_object')
plt.figure(figsize=(12, 5))
plt.boxplot(length, labels=['counts'], showmeans=True)
print('요약문_연구목표 길이 최댓값: {}'.format(np.max(length)))
print('요약문_연구목표 길이 최솟값: {}'.format(np.min(length)))
print('요약문_연구목표 길이 평균값: {}'.format(np.mean(length)))
print('요약문_연구목표 길이 중간값: {}'.format(np.median(length)))
# Out:
# 요약문_연구목표 길이 최댓값: 3951
# 요약문_연구목표 길이 최솟값: 1
# 요약문_연구목표 길이 평균값: 318.1008066366807
# 요약문_연구목표 길이 중간값: 249.0

# %%
length=train['요약문_연구내용'].astype(str).apply(len)
plt.hist(length, bins=50, alpha=0.5, color='r', label='word')
plt.title('histogram of length of summary_content')
plt.figure(figsize=(12, 5))
plt.boxplot(length, labels=['counts'], showmeans=True)
print('요약문_연구내용 길이 최댓값: {}'.format(np.max(length)))
print('요약문_연구내용 길이 최솟값: {}'.format(np.min(length)))
print('요약문_연구내용 길이 평균값: {}'.format(np.mean(length)))
print('요약문_연구내용 길이 중간값: {}'.format(np.median(length)))
# Out:
# 요약문_연구내용 길이 최댓값: 3999
# 요약문_연구내용 길이 최솟값: 1
# 요약문_연구내용 길이 평균값: 699.2930282724435
# 요약문_연구내용 길이 중간값: 597.0

# %%
length=train['요약문_기대효과'].astype(str).apply(len)
plt.hist(length, bins=50, alpha=0.5, color='r', label='word')
plt.title('histogram of length of summary_effect')
plt.figure(figsize=(12, 5))
plt.boxplot(length, labels=['counts'], showmeans=True)
print('요약문_기대효과 길이 최댓값: {}'.format(np.max(length)))
print('요약문_기대효과 길이 최솟값: {}'.format(np.min(length)))
print('요약문_기대효과 길이 평균값: {}'.format(np.mean(length)))
print('요약문_기대효과 길이 중간값: {}'.format(np.median(length)))
# Out:
# 요약문_기대효과 길이 최댓값: 3649
# 요약문_기대효과 길이 최솟값: 1
# 요약문_기대효과 길이 평균값: 400.4864374885258
# 요약문_기대효과 길이 중간값: 329.0

# %% [markdown]
# # **3. 데이터 전처리**

# %%
#해당 baseline 에서는 과제명 columns만 활용했습니다.
#다채로운 변수 활용법으로 성능을 높여주세요!
train=train[['과제명','label']]
test=test[['과제명']]

# %%
train.head(2)
# Out:
#                                                  과제명  label
# 0                       유전정보를 활용한 새로운 해충 분류군 동정기술 개발     24
# 1  대장암의 TRAIL 내성 표적 인자 발굴 및 TRAIL 반응 예측 유전자 지도 구축...      0

# %%
test.head(2)
# Out:
#                                                  과제명
# 0  R-FSSW 기술 적용 경량 차체 부품 개발 및 품질 평가를 위한 64채널 C-SC...
# 1                           다입자계를 묘사하는 편미분방정식에 대한 연구

# %%
#1. re.sub 한글 및 공백을 제외한 문자 제거
#2. okt 객체를 활용해 형태소 단위로 나눔 (morphs)
#3. remove_stopwords로 불용어 제거  
def preprocessing(text, okt, remove_stopwords=False, stop_words=[]):
    text=re.sub("[^가-힣ㄱ-ㅎㅏ-ㅣ]","", text)
    word_text=okt.morphs(text, stem=True)
    if remove_stopwords:
        word_review=[token for token in word_text if not token in stop_words]
    return word_review

# %%
# 불용어 제거
stop_words=['은','는','이','가', '하','아','것','들','의','있','되','수','보','주','등','한'] 
okt=Okt()
clean_train_text=[]
clean_test_text=[]

# %%
#시간이 많이 걸립니다.
for text in tqdm.tqdm(train['과제명']):
    try:
        clean_train_text.append(preprocessing(text, okt, remove_stopwords=True, stop_words=stop_words))
    except:
        clean_train_text.append([])
# Out:
# 100%|██████████| 174304/174304 [55:52<00:00, 51.99it/s]

# %%
for text in tqdm.tqdm(test['과제명']):
    if type(text) == str:
        clean_test_text.append(preprocessing(text, okt, remove_stopwords=True, stop_words=stop_words))
    else:
        clean_test_text.append([])
# Out:
# 100%|██████████| 43576/43576 [16:05<00:00, 45.12it/s]

# %%
print(len(clean_train_text))
print(len(clean_test_text))
# Out:
# 174304
# 43576

# %%
#텐서플로의 전처리 모듈을 활용해 토크나이징 객체를 만든 후 인덱스 벡터로 전환
tokenizer=Tokenizer()
tokenizer.fit_on_texts(clean_train_text)

# %%
# texts_to_sequences() 메서드는 텍스트 안의 단어들을 숫자의 시퀀스의 형태로 변환
train_sequences=tokenizer.texts_to_sequences(clean_train_text)
test_sequences=tokenizer.texts_to_sequences(clean_test_text)

# Tokenizer는 문장으로부터 단어를 토큰화하고 숫자에 대응시키는 딕셔너리를 사용할 수 있도록 함
word_vocab=tokenizer.word_index

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# - pad_sequences 함수 파라미터 설명
#   - padding : 'post'로 지정하면 시퀀스의 뒤에 패딩이 채워짐 (기본값 : 'pre')
#   - maxlen : 시퀀스의 최대 길이를 제한
#   - truncating : 최대 길이를 넘는 시퀀스를 잘라낼 위치를 지정 'post'를 지정하면 뒷부분을 잘라냄

# %%
# 패딩 처리
# pad_sequences함수는 가장 긴 sequences 길이에 맞춰서 숫자 0을 이용해서 같은 길이의 시퀀스로 변환
train_inputs=pad_sequences(train_sequences, maxlen=40, padding='post')
test_inputs=pad_sequences(test_sequences, maxlen=40, padding='post')

# %%
print(word_vocab)
# Out:
# {'개발': 1, '및': 2, '을': 3, '기술': 4, '연구': 5, '위': 6, '를': 7, '성': 8, '시스템': 9, '형': 10, '에': 11, '적': 12, '기': 13, '기반': 14, '화': 15, '과': 16, '고': 17, '반': 18, '용한': 19, '통한': 20, '용': 21, '기능': 22, '활용': 23, '평가': 24, '분석': 25, '치료': 26, '사업': 27, '이용': 28, '제': 29, '저': 30, '에서': 31, '전': 32, '구축': 33, '관리': 34, '조절': 35, '와': 36, '규명': 37, '내': 38, '되다': 39, '적용': 40, '상': 41, '소재': 42, '모델': 43, '플랫폼': 44, '원': 45, '연': 46, '복합': 47, '대': 48, '제어': 49, '환경': 50, '공정': 51, '물질': 52, '스마트': 53, '생산': 54, '구': 55, '소': 56, '인': 57, '기전': 58, '효율': 59, '자': 60, '진단': 61, '에의': 62, '세포': 63, '개선': 64, '조': 65, '특성': 66, '지': 67, '나노': 68, '동': 69, '계': 70, '유전자': 71, '에너지': 72, '신': 73, '분': 74, '바이오': 75, '정보': 76, '제품': 77, '센서': 78, '통합': 79, '융합': 80, '지능': 81, '관': 82, '질환': 83, '서비스': 84, '발굴': 85, '응용': 86, '장치': 87, '효과': 88, '급': 89, '공': 90, '설계': 91, '암': 92, '구조': 93, '향상': 94, '식': 95, '기법': 96, '예측': 97, '지역': 98, '제조': 99, '가능하다': 100, '단': 101, '재개발': 102, '영상': 103, '산업': 104, '도': 105, '으로': 106, '에서의': 107, '다': 108, '모듈': 109, '성능': 110, '반응': 111, '로': 112, '검증': 113, '영향': 114, '시': 115, '환자': 116, '단백질': 117, '차세대': 118, '차원': 119, '지원': 120, '발생': 121, '작': 122, '유래': 123, '비': 124, '줄기세포': 125, '시험': 126, '안전': 127, '면역': 128, '대한': 129, '모니터링': 130, '생체': 131, '네트워크': 132, '맞춤': 133, '열': 134, '체': 135, '식품': 136, '운영': 137, '데이터': 138, '석': 139, '측정': 140, '법': 141, '하다': 142, '미세': 143, '핵심': 144, '최적화': 145, '품종': 146, '속': 147, '품질': 148, '어': 149, '중': 150, '용다': 151, '합성': 152, '경': 153, '빅데이터': 154, '체계': 155, '전달': 156, '극': 157, '유전체': 158, '표적': 159, '미치다': 160, '따른': 161, '장': 162, '간': 163, '다중': 164, '실시간': 165, '분자': 166, '방법': 167, '양성': 168, '별': 169, '장비': 170, '역할': 171, '인공': 172, '대응': 173, '친환경': 174, '새롭다': 175, '양': 176, '신호': 177, '처리': 178, '관련': 179, '사': 180, '하이브리드': 181, '활': 182, '부품': 183, '변화': 184, '정밀': 185, '금속': 186, '임': 187, '중심': 188, '온': 189, '러닝': 190, '건강': 191, '초': 192, '항': 193, '전력': 194, '마커': 195, '약물': 196, '표준': 197, '보안': 198, '조사': 199, '신규': 200, '탐색': 201, '로봇': 202, '감': 203, '추다': 204, '미생물': 205, '실증': 206, '광': 207, '제작': 208, '자동': 209, '모': 210, '생': 211, '현장': 212, '효능': 213, '력': 214, '방안': 215, '적응': 216, '바이러스': 217, '해양': 218, '재배': 219, '전략': 220, '프로그램': 221, '식물': 222, '작물': 223, '강화': 224, '안전성': 225, '혈관': 226, '물': 227, '알고리즘': 228, '측': 229, '센터': 230, '마이크로': 231, '시설': 232, '약': 233, '의료': 234, '촉매': 235, '층': 236, '한국': 237, '반도체': 238, '수출': 239, '예방': 240, '고성능': 241, '상호작용': 242, '뇌': 243, '소자': 244, '신뢰': 245, '유도': 246, '추출': 247, '천': 248, '최적': 249, '사용': 250, '상용': 251, '안정': 252, '이상': 253, '자원': 254, '증진': 255, '특이': 256, '토양': 257, '차량': 258, '육성': 259, '인자': 260, '국내': 261, '자동차': 262, '근': 263, '검사': 264, '발현': 265, '동물': 266, '영': 267, '섬유': 268, '구현': 269, '분리': 270, '기획': 271, '국산': 272, '경량': 273, '확립': 274, '유기': 275, '딥': 276, '표면': 277, '재생': 278, '가스': 279, '갖다': 280, '물의': 281, '확보': 282, '표준화': 283, '방지': 284, '솔루션': 285, '염증': 286, '활성화': 287, '초고': 288, '글로벌': 289, '무선': 290, '인력': 291, '재료': 292, '해석': 293, '탄소': 294, '그': 295, '방식': 296, '계통': 297, '조직': 298, '기기': 299, '개': 300, '과제': 301, '고분자': 302, '생물': 303, '인지': 304, '육': 305, '유효': 306, '기준': 307, '손상': 308, '종양': 309, '성향': 310, '연료': 311, '사회': 312, '세': 313, '가공': 314, '억제': 315, '과정': 316, '위험': 317, '실용': 318, '스트레스': 319, '전자': 320, '디자인': 321, '트': 322, '교육': 323, '미래': 324, '멀티': 325, '모바일': 326, '콘텐츠': 327, '공간': 328, '이를': 329, '제거': 330, '모델링': 331, '유해': 332, '협력': 333, '모형': 334, '클라우드': 335, '프린팅': 336, '검': 337, '자동화': 338, '자율': 339, '피부': 340, '화장품': 341, '크다': 342, '국제': 343, '코팅': 344, '농업': 345, '대사': 346, '레이저': 347, '메커니즘': 348, '여': 349, '선택': 350, '연구개발': 351, '고도화': 352, '검정': 353, '나노입자': 354, '용량': 355, '항성': 356, '산화': 357, '분화': 358, '백': 359, '균': 360, '감염': 361, '선도': 362, '종': 363, '학습': 364, '혁신': 365, '유전': 366, '촉진': 367, '박막': 368, '기초': 369, '웨어': 370, '작용': 371, '화학': 372, '생리': 373, '주요': 374, '양자': 375,  ...

# %%
train_sequences[0]
# Out:
# [366, 76, 7, 23, 677, 670, 639, 7509, 1154, 4, 1]

# %%
train_inputs
# Out:
# array([[  366,    76,     7, ...,     0,     0,     0],
#        [  608,    38,     8, ...,     0,     0,     0],
#        [12071,  1383,  1667, ...,     0,     0,     0],
#        ...,
#        [  222,   158,    76, ...,     0,     0,     0],
#        [  779,    71,    45, ...,     0,     0,     0],
#        [  441, 18416,    49, ...,     0,     0,     0]], dtype=int32)

# %%
print(train_inputs.shape)
print(test_inputs.shape)
# Out:
# (174304, 40)
# (43576, 40)

# %%
labels=np.array(train['label'])
len(set(labels))
# Out:
# 46

# %%
labels
# Out:
# array([24,  0,  0, ...,  0, 23,  0])

# %%
#추후 재사용 가능하도록 npy로 전환
DATA_IN_PATH='/content/gdrive/MyDrive/dacon 자연어 기반 기후 기술 분류/data_in/'
TRAIN_INPUT_DATA = 'train_input.npy'
TEST_INPUT_DATA = 'test_input.npy'

import os
if not os.path.exists(DATA_IN_PATH):
    os.makedirs(DATA_IN_PATH)
    
np.save(open(DATA_IN_PATH+TRAIN_INPUT_DATA, 'wb'), train_inputs)
np.save(open(DATA_IN_PATH+TEST_INPUT_DATA, 'wb'), test_inputs)

data_configs={}
data_configs['vocab']=word_vocab
data_configs['vocab_size'] = len(word_vocab)+1
json.dump(data_configs, open(DATA_IN_PATH+'data_configs.json', 'w'), ensure_ascii=False)

# %%
# 저장한 데이터 불러오기
train_inputs = np.load('/content/gdrive/MyDrive/dacon 자연어 기반 기후 기술 분류/data_in/train_input.npy')
test_inputs =  np.load('/content/gdrive/MyDrive/dacon 자연어 기반 기후 기술 분류/data_in/test_input.npy')
print(train_inputs)
# Out:
# [[  366    76     7 ...     0     0     0]
#  [  608    38     8 ...     0     0     0]
#  [12071  1383  1667 ...     0     0     0]
#  ...
#  [  222   158    76 ...     0     0     0]
#  [  779    71    45 ...     0     0     0]
#  [  441 18416    49 ...     0     0     0]]

# %% [markdown]
# # **4. 모델링**

# %%
#파라미터 설정
vocab_size =data_configs['vocab_size']
embedding_dim = 32
max_length = 40
oov_tok = "<OOV>"

# %%
vocab_size
# Out:
# 30403

# %%
#가벼운 NLP모델 생성
model = tf.keras.Sequential([
    tf.keras.layers.Embedding(vocab_size, embedding_dim, input_length=max_length),
    tf.keras.layers.GlobalAveragePooling1D(),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dense(46, activation='softmax')
])

# compile model
model.compile(loss='sparse_categorical_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

# model summary
print(model.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding (Embedding)        (None, 40, 32)            972896
# _________________________________________________________________
# global_average_pooling1d (Gl (None, 32)                0
# _________________________________________________________________
# dense (Dense)                (None, 128)               4224
# _________________________________________________________________
# dense_1 (Dense)              (None, 46)                5934
# =================================================================
# Total params: 983,054
# Trainable params: 983,054
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
# fit model
num_epochs = 30
history = model.fit(train_inputs, labels, 
                    epochs=num_epochs, verbose=2, 
                    validation_split=0.2)
# Out:
# Epoch 1/30
# 4358/4358 - 60s - loss: 0.9275 - accuracy: 0.8203 - val_loss: 0.8059 - val_accuracy: 0.8246
# Epoch 2/30
# 4358/4358 - 54s - loss: 0.6617 - accuracy: 0.8416 - val_loss: 0.6385 - val_accuracy: 0.8453
# Epoch 3/30
# 4358/4358 - 50s - loss: 0.5177 - accuracy: 0.8653 - val_loss: 0.5558 - val_accuracy: 0.8574
# Epoch 4/30
# 4358/4358 - 52s - loss: 0.4317 - accuracy: 0.8814 - val_loss: 0.5157 - val_accuracy: 0.8686
# Epoch 5/30
# 4358/4358 - 55s - loss: 0.3708 - accuracy: 0.8952 - val_loss: 0.4919 - val_accuracy: 0.8729
# Epoch 6/30
# 4358/4358 - 53s - loss: 0.3267 - accuracy: 0.9059 - val_loss: 0.4783 - val_accuracy: 0.8776
# Epoch 7/30
# 4358/4358 - 53s - loss: 0.2916 - accuracy: 0.9147 - val_loss: 0.4775 - val_accuracy: 0.8821
# Epoch 8/30
# 4358/4358 - 50s - loss: 0.2636 - accuracy: 0.9223 - val_loss: 0.4716 - val_accuracy: 0.8845
# Epoch 9/30
# 4358/4358 - 52s - loss: 0.2401 - accuracy: 0.9284 - val_loss: 0.4832 - val_accuracy: 0.8875
# Epoch 10/30
# 4358/4358 - 53s - loss: 0.2211 - accuracy: 0.9339 - val_loss: 0.4897 - val_accuracy: 0.8891
# Epoch 11/30
# 4358/4358 - 53s - loss: 0.2049 - accuracy: 0.9383 - val_loss: 0.4986 - val_accuracy: 0.8911
# Epoch 12/30
# 4358/4358 - 56s - loss: 0.1901 - accuracy: 0.9420 - val_loss: 0.4961 - val_accuracy: 0.8919
# Epoch 13/30
# 4358/4358 - 56s - loss: 0.1772 - accuracy: 0.9458 - val_loss: 0.5097 - val_accuracy: 0.8925
# Epoch 14/30
# 4358/4358 - 50s - loss: 0.1659 - accuracy: 0.9493 - val_loss: 0.5263 - val_accuracy: 0.8920
# Epoch 15/30
# 4358/4358 - 51s - loss: 0.1557 - accuracy: 0.9516 - val_loss: 0.5339 - val_accuracy: 0.8928
# Epoch 16/30
# 4358/4358 - 52s - loss: 0.1463 - accuracy: 0.9545 - val_loss: 0.5462 - val_accuracy: 0.8905
# Epoch 17/30
# 4358/4358 - 55s - loss: 0.1380 - accuracy: 0.9567 - val_loss: 0.5524 - val_accuracy: 0.8902
# Epoch 18/30
# 4358/4358 - 54s - loss: 0.1299 - accuracy: 0.9594 - val_loss: 0.5747 - val_accuracy: 0.8935
# Epoch 19/30
# 4358/4358 - 56s - loss: 0.1231 - accuracy: 0.9608 - val_loss: 0.5856 - val_accuracy: 0.8926
# Epoch 20/30
# 4358/4358 - 55s - loss: 0.1158 - accuracy: 0.9631 - val_loss: 0.6122 - val_accuracy: 0.8972
# Epoch 21/30
# 4358/4358 - 56s - loss: 0.1102 - accuracy: 0.9648 - val_loss: 0.6121 - val_accuracy: 0.8961
# Epoch 22/30
# 4358/4358 - 54s - loss: 0.1047 - accuracy: 0.9668 - val_loss: 0.6347 - val_accuracy: 0.8973
# Epoch 23/30
# 4358/4358 - 53s - loss: 0.0998 - accuracy: 0.9681 - val_loss: 0.6676 - val_accuracy: 0.8974
# Epoch 24/30
# 4358/4358 - 52s - loss: 0.0953 - accuracy: 0.9693 - val_loss: 0.6651 - val_accuracy: 0.8969
# Epoch 25/30
# 4358/4358 - 59s - loss: 0.0906 - accuracy: 0.9701 - val_loss: 0.6800 - val_accuracy: 0.8980
# Epoch 26/30
# 4358/4358 - 54s - loss: 0.0867 - accuracy: 0.9717 - val_loss: 0.7027 - val_accuracy: 0.8994
# Epoch 27/30
# 4358/4358 - 55s - loss: 0.0831 - accuracy: 0.9729 - val_loss: 0.7168 - val_accuracy: 0.8941
# Epoch 28/30
# 4358/4358 - 56s - loss: 0.0799 - accuracy: 0.9737 - val_loss: 0.7197 - val_accuracy: 0.8984
# Epoch 29/30
# 4358/4358 - 53s - loss: 0.0762 - accuracy: 0.9752 - val_loss: 0.7587 - val_accuracy: 0.9024
# Epoch 30/30
# 4358/4358 - 57s - loss: 0.0735 - accuracy: 0.9760 - val_loss: 0.7664 - val_accuracy: 0.8991

# %%
model.save('/content/gdrive/MyDrive/dacon 자연어 기반 기후 기술 분류/dacon_자연어기반 기후기술분류/my_model.h5')

# %% [markdown]
# # **5. 예측 후 제출하기**

# %%
#평가지표가 Macro F1이기에 확률값으로 결과를 내면 안됩니다.
pred=model.predict(test_inputs)
pred=tf.argmax(pred, axis=1)

# %%
sample_submission['label']=pred

# %%
sample_submission
# Out:
#         index  label
# 0      174304      0
# 1      174305      0
# 2      174306      0
# 3      174307      0
# 4      174308      0
# ...       ...    ...
# 43571  217875      0
# 43572  217876      0
# 43573  217877      2
# 43574  217878      0
# 43575  217879     19
#
# [43576 rows x 2 columns]

# %%
sample_submission.to_csv('/content/gdrive/MyDrive/dacon 자연어 기반 기후 기술 분류/dacon_자연어기반 기후기술분류/open/baseline.csv', index=False)
